# %%
import os
import sys

# %%
#Mount the google drive
from google.colab import drive
drive.mount( '/content/drive', force_remount=True )
# Out:
# Mounted at /content/drive

# %%
sys.path.append("/content/drive/My Drive/TSAI_EVA4/Session 14-15A/")
os.chdir('/content/drive/My Drive/TSAI_EVA4/Session 14-15A/')

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/TSAI_EVA4/Session 14-15A'

# %%
# !wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5 -O ./DenseDepth/nyu.h5
# Out:
# --2020-05-05 14:27:07--  https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.108.179
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.108.179|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 172897376 (165M) [application/h5]
# Saving to: ‘./DenseDepth/nyu.h5’
#
# ./DenseDepth/nyu.h5 100%[===================>] 164.89M  18.1MB/s    in 11s
#
# 2020-05-05 14:27:19 (15.5 MB/s) - ‘./DenseDepth/nyu.h5’ saved [172897376/172897376]

# %%
# !cd DenseDepth; python test.py --input "examples/*.png"
# Out:
# Using TensorFlow backend.
# Loading model...
#
# Model loaded (nyu.h5).
#
# Loaded (15) images of size (480, 640, 3).
# (15, 240, 320, 1) (15, 480, 640, 3)
# (960, 2560, 3)
# <Figure size 224x224 with 1 Axes>
# <Figure size 224x224 with 1 Axes>
# <Figure size 224x224 with 1 Axes>
# <Figure size 224x224 with 1 Axes>
# <Figure size 224x224 with 1 Axes>
# <Figure size 224x224 with 1 Axes>
# <Figure size 224x224 with 1 Axes>
# <Figure size 224x224 with 1 Axes>
# <Figure size 224x224 with 1 Axes>
# <Figure size 224x224 with 1 Axes>
# <Figure size 224x224 with 1 Axes>
# <Figure size 224x224 with 1 Axes>
# <Figure size 224x224 with 1 Axes>
# <Figure size 224x224 with 1 Axes>
# <Figure size 224x224 with 1 Axes>
# <Figure size 1000x500 with 1 Axes>

# %%
 # !cd DenseDepth
# !ls

# %%
from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(20,20))
plt.imshow( io.imread('./DenseDepth/test.png') )

# %%
from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(20,20))
plt.imshow( io.imread('./org_fg_bg.png') )
