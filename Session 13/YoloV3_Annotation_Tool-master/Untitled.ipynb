# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from PIL import Image  
import PIL  
  
# creating a image object (main image)  
im1 = Image.open("Images/images_0.jpg")  

# /media/chintu/bharath_ext_hdd/Bharath/EVA4/TSAI-Assignments-EVA4/Session13/YoloV3_Annotation_Tool-master/Images
  
# save a image using extension 
# im1 = im1.save("geeks.jpg") 
plt.imshow(im1)
im1.size
im1 = im1.resize((400, 400))

# %%
# Out:
# (940, 525)

# %%
im1.save("im1.jpg")
